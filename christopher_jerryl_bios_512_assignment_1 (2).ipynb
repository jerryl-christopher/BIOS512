# %%
library('tidyverse')
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.2 ──
# ✔ ggplot2 3.4.2     ✔ purrr   1.0.1
# ✔ tibble  3.2.1     ✔ dplyr   1.1.2
# ✔ tidyr   1.3.0     ✔ stringr 1.5.0
# ✔ readr   2.1.4     ✔ forcats 1.0.0
# Warning message:
# “package ‘ggplot2’ was built under R version 4.2.3”
# Warning message:
# “package ‘tibble’ was built under R version 4.2.3”
# Warning message:
# “package ‘dplyr’ was built under R version 4.2.3”
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
library('palmerpenguins')

# %%
options(repr.plot.res = 250, repr.plot.height = 3, repr.plot.width = 4)

# %% [markdown]
# * filter() and lag() have conflicts with other funtions in my R sesison

# %%
penguins |> head()
# Out:
#   species island    bill_length_mm bill_depth_mm flipper_length_mm body_mass_g
# 1 Adelie  Torgersen 39.1           18.7          181               3750
# 2 Adelie  Torgersen 39.5           17.4          186               3800
# 3 Adelie  Torgersen 40.3           18.0          195               3250
# 4 Adelie  Torgersen   NA             NA           NA                 NA
# 5 Adelie  Torgersen 36.7           19.3          193               3450
# 6 Adelie  Torgersen 39.3           20.6          190               3650
#   sex    year
# 1 male   2007
# 2 female 2007
# 3 female 2007
# 4 NA     2007
# 5 female 2007
# 6 male   2007

# %%
penguins |> ggplot(
    mapping = aes(x = bill_length_mm, y = bill_depth_mm)) +
    geom_point()+
    labs(
    title = "Bill Length and Bill Depth of Penguins",
    subtitle = "In 3 Species of Penguins",
    x = "Bill Length (mm)",
    y = "Bill Depth (mm)"
  )
# Out:
# Warning message:
# “Removed 2 rows containing missing values (`geom_point()`).”
# plot without title

# %%
penguins |> ggplot(
    mapping = aes(x = bill_length_mm, y = bill_depth_mm)) +
    geom_point(mapping = aes(color = species))+
    scale_color_brewer(palette = 'Set2')+
    labs(
    title = "Bill Length and Bill Depth of Penguins",
    subtitle = "In 3 Species of Penguins",
    x = "Bill Length (mm)",
    y = "Bill Depth (mm)",
    color = "Species"
  )
# Out:
# Warning message:
# “Removed 2 rows containing missing values (`geom_point()`).”
# plot without title

# %%
penguins |> ggplot(aes(x = fct_infreq(island))) +
  geom_bar(fill= 'steelblue') +
  labs(x = "Island", y = "Count") +
  coord_flip()
# Out:
# plot without title
